# %% [markdown]
# ### Evolução da indexação SciELO Brasil
# A descrição das regras e fontes de dados estão neste issue:
#
# https://github.com/scieloorg/scielo_dltools/issues/24

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Carga do CSV com os metadados de documentos

# %%
df = pd.read_csv('documents_licenses.csv', low_memory=False, keep_default_na=False)

# %%
# Visualiza os 3 primeiros registros
df.head(3)
# Out:
#   extraction date study unit collection ISSN SciELO               ISSN's  \
# 0      2022-02-09   document        scl   0100-879X  0100-879X;1414-431X
# 1      2022-02-09   document        scl   0100-879X  0100-879X;1414-431X
# 2      2022-02-09   document        scl   0100-879X  0100-879X;1414-431X
#
#                                      title at SciELO  \
# 0  Brazilian Journal of Medical and Biological Re...
# 1  Brazilian Journal of Medical and Biological Re...
# 2  Brazilian Journal of Medical and Biological Re...
#
#                   title thematic areas  title is agricultural sciences  \
# 0  Biological Sciences;Health Sciences                               0
# 1  Biological Sciences;Health Sciences                               0
# 2  Biological Sciences;Health Sciences                               0
#
#    title is applied social sciences  title is biological sciences  ...  \
# 0                                 0                             1  ...
# 1                                 0                             1  ...
# 2                                 0                             1  ...
#
#    title is health sciences  title is human sciences  \
# 0                         1                        0
# 1                         1                        0
# 2                         1                        0
#
#    title is linguistics, letters and arts  title is multidisciplinary  \
# 0                                       0                           0
# 1                                       0                           0
# 2                                       0                           0
#
#    title current status  document publishing ID (PID SciELO)  \
# 0               current              S0100-879X1998000800006
# 1               current              S0100-879X1998000800011
# 2               current              S0100-879X1998000800005
#
#   document publishing year        document type  document is citable  \
# 0                     1998     research-article                    1
# 1                     1998  rapid-communication                    1
# 2                     1998     research-article                    1
#
#   document license
# 0           by/4.0
# 1           by/4.0
# 2           by/4.0
#
# [3 rows x 22 columns]

# %%
# Total de Linhas e colunas
df.shape
# Out:
# (456482, 22)

# %%
# Nome das colunas
df.columns
# Out:
# Index(['extraction date', 'study unit', 'collection', 'ISSN SciELO', 'ISSN's',
#        'title at SciELO', 'title thematic areas',
#        'title is agricultural sciences', 'title is applied social sciences',
#        'title is biological sciences', 'title is engineering',
#        'title is exact and earth sciences', 'title is health sciences',
#        'title is human sciences', 'title is linguistics, letters and arts',
#        'title is multidisciplinary', 'title current status',
#        'document publishing ID (PID SciELO)', 'document publishing year',
#        'document type', 'document is citable', 'document license'],
#       dtype='object')

# %%
# Filtra documentos a partir de 1997 (ano que se inicia o projeto SciELO) em novo DataFrame
ndf = df[df['document publishing year'] >= 1997]

# %%
# Total de Linhas e colunas
ndf.shape
# Out:
# (428724, 22)

# %%
gb_docs_issn = ndf.groupby(['ISSN SciELO','document publishing year']).count()\
             .unstack(fill_value=0).stack()['document publishing ID (PID SciELO)']
gb_docs_issn
# Out:
# ISSN SciELO  document publishing year
# 0001-3714    1997                         0
#              1998                        33
#              1999                        64
#              2000                         0
#              2001                         0
#                                          ..
# 2676-0029    2020                         0
#              2021                        41
#              2022                         0
#              2023                         0
#              2024                         0
# Name: document publishing ID (PID SciELO), Length: 10892, dtype: int64

# %%
type(gb_docs_issn)
# Out:
# pandas.core.series.Series

# %%
# Converte o objeto tipo Series (do groupby) em DataFrame
docs_issn = pd.DataFrame(gb_docs_issn.to_frame().to_records())
docs_issn
# Out:
#       ISSN SciELO  document publishing year  \
# 0       0001-3714                      1997
# 1       0001-3714                      1998
# 2       0001-3714                      1999
# 3       0001-3714                      2000
# 4       0001-3714                      2001
# ...           ...                       ...
# 10887   2676-0029                      2020
# 10888   2676-0029                      2021
# 10889   2676-0029                      2022
# 10890   2676-0029                      2023
# 10891   2676-0029                      2024
#
#        document publishing ID (PID SciELO)
# 0                                        0
# 1                                       33
# 2                                       64
# 3                                        0
# 4                                        0
# ...                                    ...
# 10887                                    0
# 10888                                   41
# 10889                                    0
# 10890                                    0
# 10891                                    0
#
# [10892 rows x 3 columns]

# %%
# Renomeia colunas para facilitar o uso posteriormente
docs_issn.rename(columns={'ISSN SciELO': 'issn_scielo', 
                          'document publishing year':'publication_year', 
                          'document publishing ID (PID SciELO)':'docs_count'}, inplace=True)
docs_issn
# Out:
#       issn_scielo  publication_year  docs_count
# 0       0001-3714              1997           0
# 1       0001-3714              1998          33
# 2       0001-3714              1999          64
# 3       0001-3714              2000           0
# 4       0001-3714              2001           0
# ...           ...               ...         ...
# 10887   2676-0029              2020           0
# 10888   2676-0029              2021          41
# 10889   2676-0029              2022           0
# 10890   2676-0029              2023           0
# 10891   2676-0029              2024           0
#
# [10892 rows x 3 columns]

# %% [markdown]
# #### Carga do CSV com os anos de entrada e saída dos periódicos

# %%
dfio = pd.read_csv('index_scielo_scielo-year-of-entry-exit-bra.csv')
dfio
# Out:
#     issn_scielo                                            journal  \
# 0     0102-6720  ABCD. Arquivos Brasileiros de Cirurgia Digesti...
# 1     0044-5967                                     Acta Amazonica
# 2     0102-3306                            Acta Botanica Brasilica
# 3     0102-8650                          Acta Cirúrgica Brasileira
# 4     2179-975X                      Acta Limnologica Brasiliensia
# ..          ...                                                ...
# 386   1983-7151                              Turismo: Visão e Ação
# 387   2175-3369          urbe. Revista Brasileira de Gestão Urbana
# 388   0104-8775                                     Varia Historia
# 389   1809-4341            Vibrant: Virtual Brazilian Anthropology
# 390   1984-4670                                Zoologia (Curitiba)
#
#      year_of_entry  exit_year
# 0             2010        NaN
# 1             2004        NaN
# 2             2001        NaN
# 3             1998        NaN
# 4             2011        NaN
# ..             ...        ...
# 386           2020        NaN
# 387           2013        NaN
# 388           2007        NaN
# 389           2012        NaN
# 390           2009        NaN
#
# [391 rows x 4 columns]

# %%
# Garante tipagem Int para exit_year e troca NaN por Zero
dfio['exit_year'] = pd.to_numeric(dfio['exit_year'], errors='coerce')
dfio['exit_year'] = dfio['exit_year'].fillna(0).astype(int)
dfio['exit_year'].unique()
# Out:
# array([   0, 2015, 2009, 2001, 2014, 2012, 2020, 1997, 2019, 2016, 2017,
#        2011, 2013, 2005, 2004, 2007, 2010, 2003, 2002, 2021, 1999, 2018,
#        2000, 2008])

# %%
dfio
# Out:
#     issn_scielo                                            journal  \
# 0     0102-6720  ABCD. Arquivos Brasileiros de Cirurgia Digesti...
# 1     0044-5967                                     Acta Amazonica
# 2     0102-3306                            Acta Botanica Brasilica
# 3     0102-8650                          Acta Cirúrgica Brasileira
# 4     2179-975X                      Acta Limnologica Brasiliensia
# ..          ...                                                ...
# 386   1983-7151                              Turismo: Visão e Ação
# 387   2175-3369          urbe. Revista Brasileira de Gestão Urbana
# 388   0104-8775                                     Varia Historia
# 389   1809-4341            Vibrant: Virtual Brazilian Anthropology
# 390   1984-4670                                Zoologia (Curitiba)
#
#      year_of_entry  exit_year
# 0             2010          0
# 1             2004          0
# 2             2001          0
# 3             1998          0
# 4             2011          0
# ..             ...        ...
# 386           2020          0
# 387           2013          0
# 388           2007          0
# 389           2012          0
# 390           2009          0
#
# [391 rows x 4 columns]

# %% [markdown]
# ### Concatena DataFrames
# Agrega a docs_issn os anos de entrada e saída do periódico criando assim um novo DF

# %%
cdf = pd.concat([pd.merge(docs_issn, dfio, how='inner', on='issn_scielo')])
cdf
# Out:
#       issn_scielo  publication_year  docs_count  \
# 0       0001-3714              1997           0
# 1       0001-3714              1998          33
# 2       0001-3714              1999          64
# 3       0001-3714              2000           0
# 4       0001-3714              2001           0
# ...           ...               ...         ...
# 10859   2676-0029              2020           0
# 10860   2676-0029              2021          41
# 10861   2676-0029              2022           0
# 10862   2676-0029              2023           0
# 10863   2676-0029              2024           0
#
#                                                journal  year_of_entry  \
# 0                             Revista de Microbiologia           1998
# 1                             Revista de Microbiologia           1998
# 2                             Revista de Microbiologia           1998
# 3                             Revista de Microbiologia           1998
# 4                             Revista de Microbiologia           1998
# ...                                                ...            ...
# 10859  Trends in Computational and Applied Mathematics           2021
# 10860  Trends in Computational and Applied Mathematics           2021
# 10861  Trends in Computational and Applied Mathematics           2021
# 10862  Trends in Computational and Applied Mathematics           2021
# 10863  Trends in Computational and Applied Mathematics           2021
#
#        exit_year
# 0           2000
# 1           2000
# 2           2000
# 3           2000
# 4           2000
# ...          ...
# 10859          0
# 10860          0
# 10861          0
# 10862          0
# 10863          0
#
# [10864 rows x 6 columns]

# %% [markdown]
# ### Aplica algoritmo para definir se Ativo no Ano

# %%
# Ativo ou Não Ativo
'''
SE (ano_entrada <= ano_publicacao AND (data_saida == None OR data_saida >= ano_publicacao) AND num_docs > 0):
  está ativo no ano (1)
SENÃO
  não está ativo no ano (0)
'''
cdf["active"] = np.where(
    (cdf['year_of_entry'] <= cdf['publication_year']) & 
    ((cdf['exit_year'] == 0) | (pd.to_numeric(cdf['exit_year']) >= cdf['publication_year'])) & 
    (cdf['docs_count'] > 0), 1, 0)

cdf
# Out:
#       issn_scielo  publication_year  docs_count  \
# 0       0001-3714              1997           0
# 1       0001-3714              1998          33
# 2       0001-3714              1999          64
# 3       0001-3714              2000           0
# 4       0001-3714              2001           0
# ...           ...               ...         ...
# 10859   2676-0029              2020           0
# 10860   2676-0029              2021          41
# 10861   2676-0029              2022           0
# 10862   2676-0029              2023           0
# 10863   2676-0029              2024           0
#
#                                                journal  year_of_entry  \
# 0                             Revista de Microbiologia           1998
# 1                             Revista de Microbiologia           1998
# 2                             Revista de Microbiologia           1998
# 3                             Revista de Microbiologia           1998
# 4                             Revista de Microbiologia           1998
# ...                                                ...            ...
# 10859  Trends in Computational and Applied Mathematics           2021
# 10860  Trends in Computational and Applied Mathematics           2021
# 10861  Trends in Computational and Applied Mathematics           2021
# 10862  Trends in Computational and Applied Mathematics           2021
# 10863  Trends in Computational and Applied Mathematics           2021
#
#        exit_year  active
# 0           2000       0
# 1           2000       1
# 2           2000       1
# 3           2000       0
# 4           2000       0
# ...          ...     ...
# 10859          0       0
# 10860          0       1
# 10861          0       0
# 10862          0       0
# 10863          0       0
#
# [10864 rows x 7 columns]

# %% [markdown]
# #### Tabula Ativos
# Filtra periódicos ativos e ano de publicação até o ano corrente.
#
# Agrupa por ano de publicação e renomeia a coluna "issn_scielo" para "ativos".

# %%
ativos = pd.DataFrame(cdf[(cdf["active"] == 1)].groupby('publication_year').count()['issn_scielo'])
ativos.rename(columns={'issn_scielo':'ativos'}, inplace=True)
ativos
# Out:
#                   ativos
# publication_year
# 1997                   9
# 1998                  27
# 1999                  38
# 2000                  54
# 2001                  66
# 2002                  91
# 2003                 107
# 2004                 120
# 2005                 133
# 2006                 158
# 2007                 189
# 2008                 196
# 2009                 203
# 2010                 220
# 2011                 241
# 2012                 261
# 2013                 280
# 2014                 281
# 2015                 285
# 2016                 290
# 2017                 290
# 2018                 293
# 2019                 297
# 2020                 300
# 2021                 307
# 2022                 123
# 2023                   2
# 2024                   1

# %% [markdown]
# #### Tabula Indexados
# Agrupa por ano de entrada

# %%
indexados = pd.DataFrame(dfio.groupby(['year_of_entry']).count()['issn_scielo'])
indexados
# Out:
#                issn_scielo
# year_of_entry
# 1997                    10
# 1998                    19
# 1999                    12
# 2000                    18
# 2001                    13
# 2002                    27
# 2003                    18
# 2004                    16
# 2005                    15
# 2006                    27
# 2007                    31
# 2008                    10
# 2009                    11
# 2010                    21
# 2011                    24
# 2012                    30
# 2013                    30
# 2014                     2
# 2015                    11
# 2016                    10
# 2017                     8
# 2018                     6
# 2019                     7
# 2020                     6
# 2021                     9

# %% [markdown]
# Cria coluna "indexados" com o acumulado a cada ano.
#
# Renomeia o index "year_of_entry" para "publication_year" para uso posterior;
#
# Remove a coluna "issn_scielo"

# %%
indexados['indexados'] = indexados.issn_scielo.cumsum()
indexados.index.name='publication_year'
del indexados['issn_scielo']
indexados
# Out:
#                   indexados
# publication_year
# 1997                     10
# 1998                     29
# 1999                     41
# 2000                     59
# 2001                     72
# 2002                     99
# 2003                    117
# 2004                    133
# 2005                    148
# 2006                    175
# 2007                    206
# 2008                    216
# 2009                    227
# 2010                    248
# 2011                    272
# 2012                    302
# 2013                    332
# 2014                    334
# 2015                    345
# 2016                    355
# 2017                    363
# 2018                    369
# 2019                    376
# 2020                    382
# 2021                    391

# %% [markdown]
# #### Concatena Ativos e Indexados
#
# Concatena pela ativos e indexados pela chave publication_year

# %%
tab = pd.concat([pd.merge(ativos, indexados, how='inner', on='publication_year')])
tab
# Out:
#                   ativos  indexados
# publication_year
# 1997                   9         10
# 1998                  27         29
# 1999                  38         41
# 2000                  54         59
# 2001                  66         72
# 2002                  91         99
# 2003                 107        117
# 2004                 120        133
# 2005                 133        148
# 2006                 158        175
# 2007                 189        206
# 2008                 196        216
# 2009                 203        227
# 2010                 220        248
# 2011                 241        272
# 2012                 261        302
# 2013                 280        332
# 2014                 281        334
# 2015                 285        345
# 2016                 290        355
# 2017                 290        363
# 2018                 293        369
# 2019                 297        376
# 2020                 300        382
# 2021                 307        391

# %% [markdown]
# #### Desindexados
# Desindexados é subtração de indexados de ativos

# %%
tab['desindexados'] = tab['indexados']-tab['ativos']
tab
# Out:
#                   ativos  indexados  desindexados
# publication_year
# 1997                   9         10             1
# 1998                  27         29             2
# 1999                  38         41             3
# 2000                  54         59             5
# 2001                  66         72             6
# 2002                  91         99             8
# 2003                 107        117            10
# 2004                 120        133            13
# 2005                 133        148            15
# 2006                 158        175            17
# 2007                 189        206            17
# 2008                 196        216            20
# 2009                 203        227            24
# 2010                 220        248            28
# 2011                 241        272            31
# 2012                 261        302            41
# 2013                 280        332            52
# 2014                 281        334            53
# 2015                 285        345            60
# 2016                 290        355            65
# 2017                 290        363            73
# 2018                 293        369            76
# 2019                 297        376            79
# 2020                 300        382            82
# 2021                 307        391            84

# %% [markdown]
# Renomeia o index "publication_year" para "ano_publicacao"

# %%
tab.index.name='ano_publicacao'
tab
# Out:
#                 ativos  indexados  desindexados
# ano_publicacao
# 1997                 9         10             1
# 1998                27         29             2
# 1999                38         41             3
# 2000                54         59             5
# 2001                66         72             6
# 2002                91         99             8
# 2003               107        117            10
# 2004               120        133            13
# 2005               133        148            15
# 2006               158        175            17
# 2007               189        206            17
# 2008               196        216            20
# 2009               203        227            24
# 2010               220        248            28
# 2011               241        272            31
# 2012               261        302            41
# 2013               280        332            52
# 2014               281        334            53
# 2015               285        345            60
# 2016               290        355            65
# 2017               290        363            73
# 2018               293        369            76
# 2019               297        376            79
# 2020               300        382            82
# 2021               307        391            84

# %% [markdown]
# #### Exporta para Excel para verificação

# %%
tab.to_excel("rc-fapesp-evolucao-indexacao.xlsx")

# %% [markdown]
# #### Plota gráfico para verificação

# %%
import matplotlib.pyplot as plt 

x=tab.index
y1=tab['ativos']
y2=tab['indexados']
y3=tab['desindexados']

plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)

plt.title("Evolução da Indexação SciELO Brasil",fontsize=15)
plt.xlabel("X",fontsize=13)
plt.ylabel("Y",fontsize=13)
plt.show()

# %% [markdown]
# #### Exporta para CSV para envio ao Data-Lake (gold)

# %%
tab.to_csv("rc-fapesp-evolucao-indexacao.csv")
